# %%
import pandas as pd

# %%
df = pd.read_csv("not.csv")

# %%
print(df)
# Out:
#     Customer Name          age            Email   Country Purchase Amount  \
# 0   Isaac Morgan            17  ISAAC@email.com    ghana            2000
# 1        john doe  twenty five    john@email.com      USA            3000
# 2       MARY JANE          25     MARY@email.COM       Uk
# 3           Peter          200       peter@email    Kenya            5000
# 4             NaN           30      noemail@.com  Nigeria            4000
# 5            Anna           22   anna@email.com                      3500
# 6           Kwame          28    kwame@email.com    Ghana           $5300
# 7   Isaac Morgan            17   isaac@email.com    GHANA            2000
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
print(df.isnull().sum())
# Out:
# Customer Name      1
# age                0
# Email              0
# Country            0
# Purchase Amount    0
# Date               0
# dtype: int64

# %%
print(df)
# Out:
#     Customer Name          age            Email   Country Purchase Amount  \
# 0   Isaac Morgan            17  ISAAC@email.com    ghana            2000
# 1        john doe  twenty five    john@email.com      USA            3000
# 2       MARY JANE          25     MARY@email.COM       Uk
# 3           Peter          200       peter@email    Kenya            5000
# 4             NaN           30      noemail@.com  Nigeria            4000
# 5            Anna           22   anna@email.com                      3500
# 6           Kwame          28    kwame@email.com    Ghana           $5300
# 7   Isaac Morgan            17   isaac@email.com    GHANA            2000
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df["Customer Name"] = df["Customer Name"].fillna("Unknown").mode()

# %%
print(df)
# Out:
#     Customer Name          age            Email   Country Purchase Amount  \
# 0   Isaac Morgan            17  ISAAC@email.com    ghana            2000
# 1            Anna  twenty five    john@email.com      USA            3000
# 2   Isaac Morgan           25     MARY@email.COM       Uk
# 3           Kwame          200       peter@email    Kenya            5000
# 4       MARY JANE           30      noemail@.com  Nigeria            4000
# 5           Peter           22   anna@email.com                      3500
# 6         Unknown          28    kwame@email.com    Ghana           $5300
# 7        john doe           17   isaac@email.com    GHANA            2000
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
print(df.isnull().sum())
# Out:
# Customer Name      0
# age                0
# Email              0
# Country            0
# Purchase Amount    0
# Date               0
# dtype: int64

# %%
print(df.duplicated().sum(),"Duplicates found")
# Out:
# 0 Duplicates found

# %%
df.columns
# Out:
# Index(['Customer Name', 'age', 'Email ', 'Country', 'Purchase Amount', 'Date'], dtype='str')

# %%
df["Email "] = df["Email "].str.strip()

# %%
df.columns
# Out:
# Index(['Customer Name', 'age', 'Email ', 'Country', 'Purchase Amount', 'Date'], dtype='str')

# %%
print(df)
# Out:
#     Customer Name          age           Email   Country Purchase Amount  \
# 0   Isaac Morgan            17  ISAAC@email.com   ghana            2000
# 1            Anna  twenty five   john@email.com      USA            3000
# 2   Isaac Morgan           25    MARY@email.COM       Uk
# 3           Kwame          200      peter@email    Kenya            5000
# 4       MARY JANE           30     noemail@.com  Nigeria            4000
# 5           Peter           22   anna@email.com                     3500
# 6         Unknown          28   kwame@email.com    Ghana           $5300
# 7        john doe           17  isaac@email.com    GHANA            2000
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
df.dtypes
# Out:
# Customer Name      str
# age                str
# Email              str
# Country            str
# Purchase Amount    str
# Date               str
# dtype: object

# %%
print(df)
# Out:
#     Customer Name          age           Email   Country Purchase Amount  \
# 0   Isaac Morgan            17  ISAAC@email.com   ghana            2000
# 1            Anna  twenty five   john@email.com      USA            3000
# 2   Isaac Morgan           25    MARY@email.COM       Uk
# 3           Kwame          200      peter@email    Kenya            5000
# 4       MARY JANE           30     noemail@.com  Nigeria            4000
# 5           Peter           22   anna@email.com                     3500
# 6         Unknown          28   kwame@email.com    Ghana           $5300
# 7        john doe           17  isaac@email.com    GHANA            2000
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df["age"] = pd.to_numeric(df["age"],errors="coerce")

# %%
df.dtypes
# Out:
# Customer Name          str
# age                float64
# Email                  str
# Country                str
# Purchase Amount        str
# Date                   str
# dtype: object

# %%
df["Purchase Amount"] = pd.to_numeric(df["Purchase Amount"],errors="coerce")

# %%
df.dtypes
# Out:
# Customer Name          str
# age                float64
# Email                  str
# Country                str
# Purchase Amount    float64
# Date                   str
# dtype: object

# %%
# df["Date"] = pd.to_datetime(["date"])
# print(df["Date"])

# %%
df.dtypes
# Out:
# Customer Name          str
# age                float64
# Email                  str
# Country                str
# Purchase Amount    float64
# Date                   str
# dtype: object

# %%
print(df)
# Out:
#     Customer Name    age           Email   Country  Purchase Amount  \
# 0   Isaac Morgan    17.0  ISAAC@email.com   ghana            2000.0
# 1            Anna    NaN   john@email.com      USA           3000.0
# 2   Isaac Morgan    25.0   MARY@email.COM       Uk              NaN
# 3           Kwame  200.0      peter@email    Kenya           5000.0
# 4       MARY JANE   30.0     noemail@.com  Nigeria           4000.0
# 5           Peter   22.0   anna@email.com                    3500.0
# 6         Unknown   28.0  kwame@email.com    Ghana              NaN
# 7        john doe   17.0  isaac@email.com    GHANA           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
print(df)
# Out:
#     Customer Name    age           Email   Country  Purchase Amount  \
# 0   Isaac Morgan    17.0  ISAAC@email.com   ghana            2000.0
# 1            Anna    NaN   john@email.com      USA           3000.0
# 2   Isaac Morgan    25.0   MARY@email.COM       Uk              NaN
# 3           Kwame  200.0      peter@email    Kenya           5000.0
# 4       MARY JANE   30.0     noemail@.com  Nigeria           4000.0
# 5           Peter   22.0   anna@email.com                    3500.0
# 6         Unknown   28.0  kwame@email.com    Ghana              NaN
# 7        john doe   17.0  isaac@email.com    GHANA           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df["Country"] = df["Country"].astype(str)

# %%
print(df)
# Out:
#     Customer Name    age           Email   Country  Purchase Amount  \
# 0   Isaac Morgan    17.0  ISAAC@email.com   ghana            2000.0
# 1            Anna    NaN   john@email.com      USA           3000.0
# 2   Isaac Morgan    25.0   MARY@email.COM       Uk              NaN
# 3           Kwame  200.0      peter@email    Kenya           5000.0
# 4       MARY JANE   30.0     noemail@.com  Nigeria           4000.0
# 5           Peter   22.0   anna@email.com                    3500.0
# 6         Unknown   28.0  kwame@email.com    Ghana              NaN
# 7        john doe   17.0  isaac@email.com    GHANA           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df["Country"] = df["Country"].str.title()

# %%
print(df)
# Out:
#     Customer Name    age           Email   Country  Purchase Amount  \
# 0   Isaac Morgan    17.0  ISAAC@email.com   Ghana            2000.0
# 1            Anna    NaN   john@email.com      Usa           3000.0
# 2   Isaac Morgan    25.0   MARY@email.COM       Uk              NaN
# 3           Kwame  200.0      peter@email    Kenya           5000.0
# 4       MARY JANE   30.0     noemail@.com  Nigeria           4000.0
# 5           Peter   22.0   anna@email.com                    3500.0
# 6         Unknown   28.0  kwame@email.com    Ghana              NaN
# 7        john doe   17.0  isaac@email.com    Ghana           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df["age"] = df["age"].fillna(df["age"].median())

# %%
print(df)
# Out:
#     Customer Name    age           Email   Country  Purchase Amount  \
# 0   Isaac Morgan    17.0  ISAAC@email.com   Ghana            2000.0
# 1            Anna   25.0   john@email.com      Usa           3000.0
# 2   Isaac Morgan    25.0   MARY@email.COM       Uk              NaN
# 3           Kwame  200.0      peter@email    Kenya           5000.0
# 4       MARY JANE   30.0     noemail@.com  Nigeria           4000.0
# 5           Peter   22.0   anna@email.com                    3500.0
# 6         Unknown   28.0  kwame@email.com    Ghana              NaN
# 7        john doe   17.0  isaac@email.com    Ghana           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df.loc[3,"age"] = 30
print(df)
# Out:
#     Customer Name   age           Email   Country  Purchase Amount  \
# 0   Isaac Morgan   17.0  ISAAC@email.com   Ghana            2000.0
# 1            Anna  25.0   john@email.com      Usa           3000.0
# 2   Isaac Morgan   25.0   MARY@email.COM       Uk              NaN
# 3           Kwame  30.0      peter@email    Kenya           5000.0
# 4       MARY JANE  30.0     noemail@.com  Nigeria           4000.0
# 5           Peter  22.0   anna@email.com                    3500.0
# 6         Unknown  28.0  kwame@email.com    Ghana              NaN
# 7        john doe  17.0  isaac@email.com    Ghana           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df["age"] = df["age"].astype(int)

# %%
print(df)
# Out:
#     Customer Name  age           Email   Country  Purchase Amount  \
# 0   Isaac Morgan    17  ISAAC@email.com   Ghana            2000.0
# 1            Anna   25   john@email.com      Usa           3000.0
# 2   Isaac Morgan    25   MARY@email.COM       Uk              NaN
# 3           Kwame   30      peter@email    Kenya           5000.0
# 4       MARY JANE   30     noemail@.com  Nigeria           4000.0
# 5           Peter   22   anna@email.com                    3500.0
# 6         Unknown   28  kwame@email.com    Ghana              NaN
# 7        john doe   17  isaac@email.com    Ghana           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
print(df.isnull())
# Out:
#    Customer Name    age  Email   Country  Purchase Amount   Date
# 0          False  False   False    False            False  False
# 1          False  False   False    False            False  False
# 2          False  False   False    False             True  False
# 3          False  False   False    False            False  False
# 4          False  False   False    False            False  False
# 5          False  False   False    False            False  False
# 6          False  False   False    False             True  False
# 7          False  False   False    False            False  False

# %%
print(df.isnull().sum())
# Out:
# Customer Name      0
# age                0
# Email              0
# Country            0
# Purchase Amount    2
# Date               0
# dtype: int64

# %%
df["Purchase Amount"] = df["Purchase Amount"].fillna(df["Purchase Amount"].median())
print(df)
# Out:
#     Customer Name  age           Email   Country  Purchase Amount  \
# 0   Isaac Morgan    17  ISAAC@email.com   Ghana            2000.0
# 1            Anna   25   john@email.com      Usa           3000.0
# 2   Isaac Morgan    25   MARY@email.COM       Uk           3250.0
# 3           Kwame   30      peter@email    Kenya           5000.0
# 4       MARY JANE   30     noemail@.com  Nigeria           4000.0
# 5           Peter   22   anna@email.com                    3500.0
# 6         Unknown   28  kwame@email.com    Ghana           3250.0
# 7        john doe   17  isaac@email.com    Ghana           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
print(df.isnull().sum())
# Out:
# Customer Name      0
# age                0
# Email              0
# Country            0
# Purchase Amount    0
# Date               0
# dtype: int64

# %%
print(df["Date"].dtype)
# Out:
# str

# %%
df.dtypes
# Out:
# Customer Name          str
# age                  int64
# Email                  str
# Country                str
# Purchase Amount    float64
# Date                   str
# dtype: object

# %%
print(df)
# Out:
#     Customer Name  age           Email   Country  Purchase Amount  \
# 0   Isaac Morgan    17  ISAAC@email.com   Ghana            2000.0
# 1            Anna   25   john@email.com      Usa           3000.0
# 2   Isaac Morgan    25   MARY@email.COM       Uk           3250.0
# 3           Kwame   30      peter@email    Kenya           5000.0
# 4       MARY JANE   30     noemail@.com  Nigeria           4000.0
# 5           Peter   22   anna@email.com                    3500.0
# 6         Unknown   28  kwame@email.com    Ghana           3250.0
# 7        john doe   17  isaac@email.com    Ghana           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df.loc[0,"Email "] = "isaac@email.com"
df.loc[2,"Email "] = "mary@email.com"
df.loc[3,"Email "] = "peter@email.com"
df.loc[4,"Email "] = "noemail@email.com"
print(df)
print(df.duplicated())
print(df.isnull())
# Out:
#     Customer Name  age             Email   Country  Purchase Amount  \
# 0   Isaac Morgan    17    isaac@email.com   Ghana            2000.0
# 1            Anna   25     john@email.com      Usa           3000.0
# 2   Isaac Morgan    25     mary@email.com       Uk           3250.0
# 3           Kwame   30    peter@email.com    Kenya           5000.0
# 4       MARY JANE   30  noemail@email.com  Nigeria           4000.0
# 5           Peter   22     anna@email.com                    3500.0
# 6         Unknown   28    kwame@email.com    Ghana           3250.0
# 7        john doe   17    isaac@email.com    Ghana           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool
#    Customer Name    age  Email   Country  Purchase Amount   Date
# ...

# %%
df.columns
# Out:
# Index(['Customer Name', 'age', 'Email ', 'Country', 'Purchase Amount', 'Date'], dtype='str')

# %%
df["Email "] = df["Email "].str.replace(" ","")

# %%
df.columns
# Out:
# Index(['Customer Name', 'age', 'Email ', 'Country', 'Purchase Amount', 'Date'], dtype='str')

# %%
print(df)
# Out:
#     Customer Name  age             Email   Country  Purchase Amount  \
# 0   Isaac Morgan    17    isaac@email.com   Ghana            2000.0
# 1            Anna   25     john@email.com      Usa           3000.0
# 2   Isaac Morgan    25     mary@email.com       Uk           3250.0
# 3           Kwame   30    peter@email.com    Kenya           5000.0
# 4       MARY JANE   30  noemail@email.com  Nigeria           4000.0
# 5           Peter   22     anna@email.com                    3500.0
# 6         Unknown   28    kwame@email.com    Ghana           3250.0
# 7        john doe   17    isaac@email.com    Ghana           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df["Country"] = df["Country"].str.upper() 
print(df)
# Out:
#     Customer Name  age             Email   Country  Purchase Amount  \
# 0   Isaac Morgan    17    isaac@email.com   GHANA            2000.0
# 1            Anna   25     john@email.com      USA           3000.0
# 2   Isaac Morgan    25     mary@email.com       UK           3250.0
# 3           Kwame   30    peter@email.com    KENYA           5000.0
# 4       MARY JANE   30  noemail@email.com  NIGERIA           4000.0
# 5           Peter   22     anna@email.com                    3500.0
# 6         Unknown   28    kwame@email.com    GHANA           3250.0
# 7        john doe   17    isaac@email.com    GHANA           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df.loc[5,"Country"] = "AMERICA"

# %%
print(df)
# Out:
#     Customer Name  age             Email   Country  Purchase Amount  \
# 0   Isaac Morgan    17    isaac@email.com   GHANA            2000.0
# 1            Anna   25     john@email.com      USA           3000.0
# 2   Isaac Morgan    25     mary@email.com       UK           3250.0
# 3           Kwame   30    peter@email.com    KENYA           5000.0
# 4       MARY JANE   30  noemail@email.com  NIGERIA           4000.0
# 5           Peter   22     anna@email.com  AMERICA           3500.0
# 6         Unknown   28    kwame@email.com    GHANA           3250.0
# 7        john doe   17    isaac@email.com    GHANA           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df["Country"].unique()
# Out:
# <StringArray>
# ['GHANA ', 'USA', 'UK', 'KENYA', 'NIGERIA', 'AMERICA', 'GHANA']
# Length: 7, dtype: str

# %%
df["Country"].str.contains(" ")
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: Country, dtype: bool

# %%
df["Country"] = df["Country"].str.strip()

# %%
df["Country"].str.contains(" ")
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: Country, dtype: bool

# %%
df["Country"].unique()
# Out:
# <StringArray>
# ['GHANA', 'USA', 'UK', 'KENYA', 'NIGERIA', 'AMERICA']
# Length: 6, dtype: str

# %%
df.columns
# Out:
# Index(['Customer Name', 'age', 'Email ', 'Country', 'Purchase Amount', 'Date'], dtype='str')

# %%
df["Email "].unique()
# Out:
# <StringArray>
# [  'isaac@email.com',    'john@email.com',    'mary@email.com',
#    'peter@email.com', 'noemail@email.com',    'anna@email.com',
#    'kwame@email.com']
# Length: 7, dtype: str

# %%
df["Customer Name"].unique()
# Out:
# <StringArray>
# [' Isaac Morgan ',           'Anna',  'Isaac Morgan ',          'Kwame',
#       'MARY JANE',          'Peter',        'Unknown',       'john doe']
# Length: 8, dtype: str

# %%
df["age"].unique()
# Out:
# array([17, 25, 30, 22, 28])

# %%
df["Date"].unique()
# Out:
# <StringArray>
# [  '2024/01/01',   '01-02-2024',   '2024-03-01', 'March 5 2024',
#    '2024/04/01',   '2024-05-01',   '2024-06-01']
# Length: 7, dtype: str

# %%
df.columns= df.columns.str.strip().str.replace(" ","_")
print(df)
df.columns
# Out:
#     Customer_Name  age              Email  Country  Purchase_Amount  \
# 0   Isaac Morgan    17    isaac@email.com    GHANA           2000.0
# 1            Anna   25     john@email.com      USA           3000.0
# 2   Isaac Morgan    25     mary@email.com       UK           3250.0
# 3           Kwame   30    peter@email.com    KENYA           5000.0
# 4       MARY JANE   30  noemail@email.com  NIGERIA           4000.0
# 5           Peter   22     anna@email.com  AMERICA           3500.0
# 6         Unknown   28    kwame@email.com    GHANA           3250.0
# 7        john doe   17    isaac@email.com    GHANA           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01
# Index(['Customer_Name', 'age', 'Email', 'Country', 'Purchase_Amount', 'Date'], dtype='str')

# %%
print(df)
df.columns
# Out:
#     Customer_Name  age              Email  Country  Purchase_Amount  \
# 0   Isaac Morgan    17    isaac@email.com    GHANA           2000.0
# 1            Anna   25     john@email.com      USA           3000.0
# 2   Isaac Morgan    25     mary@email.com       UK           3250.0
# 3           Kwame   30    peter@email.com    KENYA           5000.0
# 4       MARY JANE   30  noemail@email.com  NIGERIA           4000.0
# 5           Peter   22     anna@email.com  AMERICA           3500.0
# 6         Unknown   28    kwame@email.com    GHANA           3250.0
# 7        john doe   17    isaac@email.com    GHANA           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01
# Index(['Customer_Name', 'age', 'Email', 'Country', 'Purchase_Amount', 'Date'], dtype='str')

# %%
print(df.isnull().sum())
# Out:
# Customer_Name      0
# age                0
# Email              0
# Country            0
# Purchase_Amount    0
# Date               0
# dtype: int64

# %%
df[df["Date"].isna()]
# Out:
# Empty DataFrame
# Columns: [Customer_Name, age, Email, Country, Purchase_Amount, Date]
# Index: []

# %%
df["Date"] = df["Date"].fillna("2025-10-7")

# %%
print(df)
# Out:
#     Customer_Name  age              Email  Country  Purchase_Amount  \
# 0   Isaac Morgan    17    isaac@email.com    GHANA           2000.0
# 1            Anna   25     john@email.com      USA           3000.0
# 2   Isaac Morgan    25     mary@email.com       UK           3250.0
# 3           Kwame   30    peter@email.com    KENYA           5000.0
# 4       MARY JANE   30  noemail@email.com  NIGERIA           4000.0
# 5           Peter   22     anna@email.com  AMERICA           3500.0
# 6         Unknown   28    kwame@email.com    GHANA           3250.0
# 7        john doe   17    isaac@email.com    GHANA           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df.dtypes
# Out:
# Customer_Name          str
# age                  int64
# Email                  str
# Country                str
# Purchase_Amount    float64
# Date                   str
# dtype: object

# %%
df["Date"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
print(df.isnull().sum())
# Out:
# Customer_Name      0
# age                0
# Email              0
# Country            0
# Purchase_Amount    0
# Date               0
# dtype: int64

# %%
pd.melt(df)
# Out:
#            variable              value
# 0     Customer_Name      Isaac Morgan
# 1     Customer_Name               Anna
# 2     Customer_Name      Isaac Morgan
# 3     Customer_Name              Kwame
# 4     Customer_Name          MARY JANE
# 5     Customer_Name              Peter
# 6     Customer_Name            Unknown
# 7     Customer_Name           john doe
# 8               age                 17
# 9               age                 25
# 10              age                 25
# 11              age                 30
# 12              age                 30
# 13              age                 22
# 14              age                 28
# 15              age                 17
# 16            Email    isaac@email.com
# 17            Email     john@email.com
# 18            Email     mary@email.com
# 19            Email    peter@email.com
# 20            Email  noemail@email.com
# 21            Email     anna@email.com
# 22            Email    kwame@email.com
# ...

# %%
print(df)
# Out:
#     Customer_Name  age              Email  Country  Purchase_Amount  \
# 0   Isaac Morgan    17    isaac@email.com    GHANA           2000.0
# 1            Anna   25     john@email.com      USA           3000.0
# 2   Isaac Morgan    25     mary@email.com       UK           3250.0
# 3           Kwame   30    peter@email.com    KENYA           5000.0
# 4       MARY JANE   30  noemail@email.com  NIGERIA           4000.0
# 5           Peter   22     anna@email.com  AMERICA           3500.0
# 6         Unknown   28    kwame@email.com    GHANA           3250.0
# 7        john doe   17    isaac@email.com    GHANA           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df["Customer_Name"] = df["Customer_Name"].str.title()

# %%
print(df)
# Out:
#     Customer_Name  age              Email  Country  Purchase_Amount  \
# 0   Isaac Morgan    17    isaac@email.com    GHANA           2000.0
# 1            Anna   25     john@email.com      USA           3000.0
# 2   Isaac Morgan    25     mary@email.com       UK           3250.0
# 3           Kwame   30    peter@email.com    KENYA           5000.0
# 4       Mary Jane   30  noemail@email.com  NIGERIA           4000.0
# 5           Peter   22     anna@email.com  AMERICA           3500.0
# 6         Unknown   28    kwame@email.com    GHANA           3250.0
# 7        John Doe   17    isaac@email.com    GHANA           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
print(df.isnull().sum())
print(df.duplicated().sum(),"Duplicate found")
print(df.dtypes)
# Out:
# Customer_Name      0
# age                0
# Email              0
# Country            0
# Purchase_Amount    0
# Date               0
# dtype: int64
# 0 Duplicate found
# Customer_Name          str
# age                  int64
# Email                  str
# Country                str
# Purchase_Amount    float64
# Date                   str
# dtype: object

# %%
df.columns
# Out:
# Index(['Customer_Name', 'age', 'Email', 'Country', 'Purchase_Amount', 'Date'], dtype='str')

# %%
print(df)
# Out:
#     Customer_Name  age              Email  Country  Purchase_Amount  \
# 0   Isaac Morgan    17    isaac@email.com    GHANA           2000.0
# 1            Anna   25     john@email.com      USA           3000.0
# 2   Isaac Morgan    25     mary@email.com       UK           3250.0
# 3           Kwame   30    peter@email.com    KENYA           5000.0
# 4       Mary Jane   30  noemail@email.com  NIGERIA           4000.0
# 5           Peter   22     anna@email.com  AMERICA           3500.0
# 6         Unknown   28    kwame@email.com    GHANA           3250.0
# 7        John Doe   17    isaac@email.com    GHANA           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df["Customer_Name"].unique()
# Out:
# <StringArray>
# [' Isaac Morgan ',           'Anna',  'Isaac Morgan ',          'Kwame',
#       'Mary Jane',          'Peter',        'Unknown',       'John Doe']
# Length: 8, dtype: str

# %%
df["Customer_Name"] = df["Customer_Name"].str.strip()

# %%
df["Customer_Name"].unique()
# Out:
# <StringArray>
# ['Isaac Morgan', 'Anna', 'Kwame', 'Mary Jane', 'Peter', 'Unknown', 'John Doe']
# Length: 7, dtype: str

# %%
df["age"].unique()
# Out:
# array([17, 25, 30, 22, 28])

# %%
print(df)
# Out:
#   Customer_Name  age              Email  Country  Purchase_Amount  \
# 0  Isaac Morgan   17    isaac@email.com    GHANA           2000.0
# 1          Anna   25     john@email.com      USA           3000.0
# 2  Isaac Morgan   25     mary@email.com       UK           3250.0
# 3         Kwame   30    peter@email.com    KENYA           5000.0
# 4     Mary Jane   30  noemail@email.com  NIGERIA           4000.0
# 5         Peter   22     anna@email.com  AMERICA           3500.0
# 6       Unknown   28    kwame@email.com    GHANA           3250.0
# 7      John Doe   17    isaac@email.com    GHANA           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2    2024-03-01
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df = df.drop_duplicates(subset=["Customer_Name"])
print(df)
# Out:
#   Customer_Name  age              Email  Country  Purchase_Amount  \
# 0  Isaac Morgan   17    isaac@email.com    GHANA           2000.0
# 1          Anna   25     john@email.com      USA           3000.0
# 3         Kwame   30    peter@email.com    KENYA           5000.0
# 4     Mary Jane   30  noemail@email.com  NIGERIA           4000.0
# 5         Peter   22     anna@email.com  AMERICA           3500.0
# 6       Unknown   28    kwame@email.com    GHANA           3250.0
# 7      John Doe   17    isaac@email.com    GHANA           2000.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01
# 7    2024/01/01

# %%
df = df.drop_duplicates(subset=["Email"])
print(df)
# Out:
#   Customer_Name  age              Email  Country  Purchase_Amount  \
# 0  Isaac Morgan   17    isaac@email.com    GHANA           2000.0
# 1          Anna   25     john@email.com      USA           3000.0
# 3         Kwame   30    peter@email.com    KENYA           5000.0
# 4     Mary Jane   30  noemail@email.com  NIGERIA           4000.0
# 5         Peter   22     anna@email.com  AMERICA           3500.0
# 6       Unknown   28    kwame@email.com    GHANA           3250.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 3  March 5 2024
# 4    2024/04/01
# 5    2024-05-01
# 6    2024-06-01

# %%
df = df.reset_index(drop=True)
print(df)
# Out:
#   Customer_Name  age              Email  Country  Purchase_Amount  \
# 0  Isaac Morgan   17    isaac@email.com    GHANA           2000.0
# 1          Anna   25     john@email.com      USA           3000.0
# 2         Kwame   30    peter@email.com    KENYA           5000.0
# 3     Mary Jane   30  noemail@email.com  NIGERIA           4000.0
# 4         Peter   22     anna@email.com  AMERICA           3500.0
# 5       Unknown   28    kwame@email.com    GHANA           3250.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2  March 5 2024
# 3    2024/04/01
# 4    2024-05-01
# 5    2024-06-01

# %%
df.loc[5,"Customer_Name"] = "Kwame"
df.loc[2,"Customer_Name"] = "Peter"
df.loc[4,"Customer_Name"] = "Anna"
df.loc[1,"Customer_Name"] = "John"
df.loc[3,"Email"] = "maryjane@email.com"
print(df)
# Out:
#   Customer_Name  age               Email  Country  Purchase_Amount  \
# 0  Isaac Morgan   17     isaac@email.com    GHANA           2000.0
# 1          John   25      john@email.com      USA           3000.0
# 2         Peter   30     peter@email.com    KENYA           5000.0
# 3     Mary Jane   30  maryjane@email.com  NIGERIA           4000.0
# 4          Anna   22      anna@email.com  AMERICA           3500.0
# 5         Kwame   28     kwame@email.com    GHANA           3250.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2  March 5 2024
# 3    2024/04/01
# 4    2024-05-01
# 5    2024-06-01

# %%
df.loc[4,"Country"] = "UK"

# %%
print(df)
# Out:
#   Customer_Name  age               Email  Country  Purchase_Amount  \
# 0  Isaac Morgan   17     isaac@email.com    GHANA           2000.0
# 1          John   25      john@email.com      USA           3000.0
# 2         Peter   30     peter@email.com    KENYA           5000.0
# 3     Mary Jane   30  maryjane@email.com  NIGERIA           4000.0
# 4          Anna   22      anna@email.com       UK           3500.0
# 5         Kwame   28     kwame@email.com    GHANA           3250.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2  March 5 2024
# 3    2024/04/01
# 4    2024-05-01
# 5    2024-06-01

# %%
df["age"].mean()
df["Purchase_Amount"].max()
df["Country"].value_counts()
# Out:
# Country
# GHANA      2
# USA        1
# KENYA      1
# NIGERIA    1
# UK         1
# Name: count, dtype: int64

# %%
df["Email"].value_counts()
# Out:
# Email
# isaac@email.com       1
# john@email.com        1
# peter@email.com       1
# maryjane@email.com    1
# anna@email.com        1
# kwame@email.com       1
# Name: count, dtype: int64

# %%
print(df)
# Out:
#   Customer_Name  age               Email  Country  Purchase_Amount  \
# 0  Isaac Morgan   17     isaac@email.com    GHANA           2000.0
# 1          John   25      john@email.com      USA           3000.0
# 2         Peter   30     peter@email.com    KENYA           5000.0
# 3     Mary Jane   30  maryjane@email.com  NIGERIA           4000.0
# 4          Anna   22      anna@email.com       UK           3500.0
# 5         Kwame   28     kwame@email.com    GHANA           3250.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2  March 5 2024
# 3    2024/04/01
# 4    2024-05-01
# 5    2024-06-01

# %%
df.head()
# Out:
#   Customer_Name  age               Email  Country  Purchase_Amount  \
# 0  Isaac Morgan   17     isaac@email.com    GHANA           2000.0
# 1          John   25      john@email.com      USA           3000.0
# 2         Peter   30     peter@email.com    KENYA           5000.0
# 3     Mary Jane   30  maryjane@email.com  NIGERIA           4000.0
# 4          Anna   22      anna@email.com       UK           3500.0
#
#            Date
# 0    2024/01/01
# 1    01-02-2024
# 2  March 5 2024
# 3    2024/04/01
# 4    2024-05-01

# %%
df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

# %%
print(df["Date"].dtype)
# Out:
# datetime64[us]

# %%
df.head()
# Out:
#   Customer_Name  age               Email  Country  Purchase_Amount       Date
# 0  Isaac Morgan   17     isaac@email.com    GHANA           2000.0 2024-01-01
# 1          John   25      john@email.com      USA           3000.0        NaT
# 2         Peter   30     peter@email.com    KENYA           5000.0        NaT
# 3     Mary Jane   30  maryjane@email.com  NIGERIA           4000.0 2024-04-01
# 4          Anna   22      anna@email.com       UK           3500.0        NaT

# %%
df.loc[1, "Date"] = "2024-02-01"
df.loc[2, "Date"] = "2024-04-05"
df.loc[4, "Date"] = "2025-06-07"

# %%
print(df["Date"].dtype)
# Out:
# datetime64[us]

# %%
df.head()
# Out:
#   Customer_Name  age               Email  Country  Purchase_Amount       Date
# 0  Isaac Morgan   17     isaac@email.com    GHANA           2000.0 2024-01-01
# 1          John   25      john@email.com      USA           3000.0 2024-02-01
# 2         Peter   30     peter@email.com    KENYA           5000.0 2024-04-05
# 3     Mary Jane   30  maryjane@email.com  NIGERIA           4000.0 2024-04-01
# 4          Anna   22      anna@email.com       UK           3500.0 2025-06-07

# %%
df.dtypes
# Out:
# Customer_Name                 str
# age                         int64
# Email                         str
# Country                       str
# Purchase_Amount           float64
# Date               datetime64[us]
# dtype: object

# %%
df.head()
# Out:
#   Customer_Name  age               Email  Country  Purchase_Amount       Date
# 0  Isaac Morgan   17     isaac@email.com    GHANA           2000.0 2024-01-01
# 1          John   25      john@email.com      USA           3000.0 2024-02-01
# 2         Peter   30     peter@email.com    KENYA           5000.0 2024-04-05
# 3     Mary Jane   30  maryjane@email.com  NIGERIA           4000.0 2024-04-01
# 4          Anna   22      anna@email.com       UK           3500.0 2025-06-07
