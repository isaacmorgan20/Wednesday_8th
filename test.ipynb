# %% [markdown]
# Importing messy data to be cleaned

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("student_data.csv")

# %%
print(df.columns)
# Out:
# Index(['student_id', 'name', 'gender', 'class', 'math_score', 'english_score',
#        'science_score', 'history_score', 'dob', 'tuition_paid',
#        'tuition_amount', 'contact', 'address', 'house'],
#       dtype='str')

# %%
print(df["name"].tolist())
df["name"] = df["name"].str.strip().str.replace(r"\s+", " ", regex=True).str.title()
print(df["name"].tolist())
# Out:
# ['james kwame', 'Abena  Mensah', ' Kofi Adu', 'Ama Boateng', 'KWEKU ASANTE', 'james kwame', 'Efua Darko ', 'Yaw Tetteh', 'Akosua', 'Kojo Frimpong', 'Adwoa  Sarpong', 'BISMARK OWUSU', 'nana ama asante', 'Kwabena  Poku', ' Serwa Mensah', 'Fiifi Ankrah', 'ABENA KYEI', 'kofi  boateng', 'Esi Quaye ', ' Kwame Asare', 'AKUA DARKO', 'Yaw  Antwi', 'ADWOA FRIMPONG', 'kojo  mensah', 'Ama Tetteh ', ' Kweku Adu', 'NANA OWUSU', 'efua  kyei', 'Bismark Quaye ', ' Serwa Ankrah', 'KOFI ASANTE']
# ['James Kwame', 'Abena Mensah', 'Kofi Adu', 'Ama Boateng', 'Kweku Asante', 'James Kwame', 'Efua Darko', 'Yaw Tetteh', 'Akosua', 'Kojo Frimpong', 'Adwoa Sarpong', 'Bismark Owusu', 'Nana Ama Asante', 'Kwabena Poku', 'Serwa Mensah', 'Fiifi Ankrah', 'Abena Kyei', 'Kofi Boateng', 'Esi Quaye', 'Kwame Asare', 'Akua Darko', 'Yaw Antwi', 'Adwoa Frimpong', 'Kojo Mensah', 'Ama Tetteh', 'Kweku Adu', 'Nana Owusu', 'Efua Kyei', 'Bismark Quaye', 'Serwa Ankrah', 'Kofi Asante']

# %%
df["gender"] = df["gender"].str.title()
print(df["gender"].tolist())
# Out:
# ['Male', 'Female', 'M', 'Female', 'Male', 'Male', 'F', 'Male', 'Female', 'Female', 'Female', 'Male', 'F', 'Male', 'Female', 'M', 'Female', 'Male', 'F', 'Male', 'Female', 'Male', 'Female', 'M', 'Female', 'Male', 'Male', 'Female', 'M', 'F', 'Male']

# %%
df["class"] = df["class"].str.title()
print(df["class"])
# Out:
# 0      Grade 9
# 1     Grade 10
# 2      Grade 9
# 3     Grade 11
# 4     Grade 10
# 5      Grade 9
# 6     Grade 11
# 7      Grade 9
# 8     Grade 10
# 9      Grade 9
# 10    Grade 11
# 11    Grade 10
# 12     Grade 9
# 13    Grade 11
# 14    Grade 10
# 15     Grade 9
# 16    Grade 10
# 17    Grade 11
# 18     Grade 9
# 19    Grade 10
# 20    Grade 11
# 21     Grade 9
# 22    Grade 10
# 23    Grade 11
# 24     Grade 9
# 25    Grade 10
# 26    Grade 11
# 27     Grade 9
# 28    Grade 10
# 29    Grade 11
# 30     Grade 9
# Name: class, dtype: str

# %%
df.dtypes
# Out:
# student_id          int64
# name                  str
# gender                str
# class                 str
# math_score        float64
# english_score     float64
# science_score     float64
# history_score     float64
# dob                   str
# tuition_paid          str
# tuition_amount        str
# contact               str
# address               str
# house                 str
# dtype: object

# %%
median_math_score = df["math_score"].median()
df["math_score"] = df["math_score"].fillna(median_math_score)

# %%
median_english_score = df["english_score"].median()
df["english_score"] = df["english_score"].fillna(median_english_score)

# %%
median_science_score = df["science_score"].median()
df["science_score"] = df["science_score"].fillna(median_science_score)

print(df["science_score"])
# Out:
# 0     80.0
# 1     80.0
# 2     88.0
# 3     76.0
# 4     70.0
# 5     80.0
# 6     85.0
# 7     69.0
# 8     80.0
# 9     82.0
# 10    90.0
# 11    64.0
# 12    78.0
# 13    85.0
# 14    80.0
# 15    92.0
# 16    57.0
# 17    75.0
# 18    88.0
# 19    70.0
# 20    80.0
# 21    83.0
# 22    77.0
# 23    91.0
# 24    80.0
# 25    86.0
# 26    68.0
# 27    79.0
# 28    95.0
# 29    80.0
# 30    88.0
# Name: science_score, dtype: float64

# %%
median_histry_score = df["history_score"].median()
df["history_score"] = df["history_score"].fillna(median_histry_score)

print(df["history_score"])
# Out:
# 0     68.0
# 1     74.0
# 2     76.5
# 3     85.0
# 4     71.0
# 5     68.0
# 6     90.0
# 7     65.0
# 8     76.5
# 9     80.0
# 10    77.0
# 11    76.5
# 12    69.0
# 13    83.0
# 14    78.0
# 15    91.0
# 16    55.0
# 17    76.5
# 18    76.0
# 19    88.0
# 20    70.0
# 21    76.5
# 22    81.0
# 23    74.0
# 24    67.0
# 25    76.5
# 26    92.0
# 27    63.0
# 28    85.0
# 29    79.0
# 30    76.5
# Name: history_score, dtype: float64

# %%
df["dob"] = df["dob"].str.replace("-", "/")

# %%
df["tuition_paid"] = df["tuition_paid"].str.title()
print(df["tuition_paid"].tolist())
# Out:
# ['Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']

# %%
df["contact"] = df["contact"].str.replace("-", "").str.replace(" ", "")
df["contact"] = df["contact"].fillna("0024377522")
# df["contact"] = df["contact"].astype(int)
df["contact"]
# Out:
# 0     0241234567
# 1     0557654321
# 2     0241112222
# 3     0201234567
# 4     0559876543
# 5     0241234567
# 6     0278765432
# 7     0024377522
# 8     0241122334
# 9     0559988776
# 10    0274445555
# 11    0243334444
# 12    0201122334
# 13    0272223333
# 14    0024377522
# 15    0559876543
# 16    0245678901
# 17    0207654321
# 18    0551112222
# 19    0024377522
# 20    0278899001
# 21    0244445555
# 22    0201234321
# 23    0278889999
# 24    0559871234
# 25    0024377522
# 26    0249990000
# 27    0208877665
# 28    0552223333
# 29    0024377522
# 30    0271122334
# Name: contact, dtype: str

# %%
df.dtypes
# Out:
# student_id          int64
# name                  str
# gender                str
# class                 str
# math_score        float64
# english_score     float64
# science_score     float64
# history_score     float64
# dob                   str
# tuition_paid          str
# tuition_amount        str
# contact               str
# address               str
# house                 str
# dtype: object

# %%
df["address"] = df["address"].str.title() 

print(df["address"].tolist())
# Out:
# ['Accra', 'Kumasi', 'Tema', 'Accra', 'Takoradi', 'Accra', 'Kumasi', 'Tema', 'Accra', 'Takoradi', 'Kumasi', 'Accra', 'Tema', 'Kumasi', 'Accra', 'Takoradi', 'Accra', 'Kumasi', 'Tema', 'Accra', 'Takoradi', 'Accra', 'Kumasi', 'Tema', 'Accra', 'Kumasi', 'Takoradi', 'Accra', 'Kumasi', 'Tema', 'Accra']

# %%
df["house"] = df["house"].str.title()
print(df["house"].tolist())
# Out:
# ['Adenta', 'Adum', 'Community 5', 'Lapaz', 'Effia', 'Adenta', 'Nhyiaeso', 'Community 5', 'Lapaz', 'Effia', 'Adum', 'Adenta', 'Nhyiaeso', 'Adum', 'Lapaz', 'Effia', 'Adenta', 'Community 5', 'Nhyiaeso', 'Adenta', 'Lapaz', 'Effia', 'Adum', 'Community 5', 'Adenta', 'Lapaz', 'Nhyiaeso', 'Effia', 'Adenta', 'Adum', 'Community 5']

# %%
print(df)
# Out:
#     student_id             name  gender     class  math_score  english_score  \
# 0          201      James Kwame    Male   Grade 9        78.0           72.0
# 1          202     Abena Mensah  Female  Grade 10        85.0           88.0
# 2          203         Kofi Adu       M   Grade 9        92.0           95.0
# 3          204      Ama Boateng  Female  Grade 11        84.0           81.0
# 4          205     Kweku Asante    Male  Grade 10        67.0           74.0
# 5          203      James Kwame    Male   Grade 9        78.0           72.0
# 6          206       Efua Darko       F  Grade 11       110.0           89.0
# 7          207       Yaw Tetteh    Male   Grade 9        74.0           82.5
# 8          208           Akosua  Female  Grade 10        88.0           93.0
# 9          209    Kojo Frimpong  Female   Grade 9        84.0           77.0
# 10         210    Adwoa Sarpong  Female  Grade 11        91.0           85.0
# ...

# %%
print(df[df["name"].duplicated(keep=False)])
df
# Out:
#    student_id         name gender    class  math_score  english_score  \
# 0         201  James Kwame   Male  Grade 9        78.0           72.0
# 5         203  James Kwame   Male  Grade 9        78.0           72.0
#
#    science_score  history_score         dob tuition_paid tuition_amount  \
# 0           80.0           68.0  2008/05/14          Yes      GHS 1,200
# 5           80.0           68.0  2008/05/14          Yes      GHS 1,200
#
#       contact address   house
# 0  0241234567   Accra  Adenta
# 5  0241234567   Accra  Adenta
#     student_id             name  gender     class  math_score  english_score  \
# 0          201      James Kwame    Male   Grade 9        78.0           72.0
# 1          202     Abena Mensah  Female  Grade 10        85.0           88.0
# 2          203         Kofi Adu       M   Grade 9        92.0           95.0
# 3          204      Ama Boateng  Female  Grade 11        84.0           81.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   student_id      31 non-null     int64
#  1   name            31 non-null     str
#  2   gender          31 non-null     str
#  3   class           31 non-null     str
#  4   math_score      31 non-null     float64
#  5   english_score   31 non-null     float64
#  6   science_score   31 non-null     float64
#  7   history_score   31 non-null     float64
#  8   dob             31 non-null     str
#  9   tuition_paid    31 non-null     str
#  10  tuition_amount  31 non-null     str
#  11  contact         31 non-null     str
#  12  address         31 non-null     str
#  13  house           31 non-null     str
# dtypes: float64(4), int64(1), str(9)
# memory usage: 3.5 KB

# %%
df["tuition_amount"] = df["tuition_amount"].str.replace("GHS", "").str.replace(",", "")
df["tuition_amount"] = df["tuition_amount"].astype(int)
df["tuition_amount"].dtypes
# Out:
# dtype('int64')

# %%
df["dob"] = pd.to_datetime(df["dob"], dayfirst=True, errors="coerce")

df["dob"] = df["dob"].dt.strftime("%Y/%-m/%-d")

df["dob"] = df["dob"].fillna(pd.Timestamp("2000/01/01"))

df["dob"] = pd.to_datetime(df["dob"])

df.dtypes
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8136\2466614747.py:1: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["dob"] = pd.to_datetime(df["dob"], dayfirst=True, errors="coerce")
# student_id                 int64
# name                         str
# gender                       str
# class                        str
# math_score               float64
# english_score            float64
# science_score            float64
# history_score            float64
# dob               datetime64[us]
# tuition_paid                 str
# tuition_amount             int64
# contact                      str
# address                      str
# house                        str
# dtype: object

# %%
df["gender"] = df["gender"].replace({
    "M": "Male",
    "F": "Female"
})

df["gender"]
# Out:
# 0       Male
# 1     Female
# 2       Male
# 3     Female
# 4       Male
# 5       Male
# 6     Female
# 7       Male
# 8     Female
# 9     Female
# 10    Female
# 11      Male
# 12    Female
# 13      Male
# 14    Female
# 15      Male
# 16    Female
# 17      Male
# 18    Female
# 19      Male
# 20    Female
# 21      Male
# 22    Female
# 23      Male
# 24    Female
# 25      Male
# 26      Male
# 27    Female
# 28      Male
# 29    Female
# 30      Male
# Name: gender, dtype: str

# %%
# Remove duplicates
df = df.drop_duplicates(subset=["name"])
# Fix scores > 100
df.loc[df["math_score"] > 100, "math_score"] = 100
# Handle fake DOB
# df.loc[df["dob"] == "2000/01/01", "dob"] = None
# Clean contact numbers
df["contact"] = df["contact"].str.replace("00243", "0", regex=False)
# 5. Find missing/short names
df[df["name"].str.split().str.len() < 2]
# Check inconsistencies
df.groupby("address")["house"].unique()
# Out:
# address
# Accra                [Adenta, Lapaz, Effia, Community 5]
# Kumasi      [Adum, Nhyiaeso, Community 5, Lapaz, Adenta]
# Takoradi                        [Effia, Lapaz, Nhyiaeso]
# Tema                       [Community 5, Nhyiaeso, Adum]
# Name: house, dtype: object

# %%
df.to_csv("clean.csv", index=False)
